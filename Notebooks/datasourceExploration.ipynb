# %%
import os 
from dotenv import load_dotenv
import requests
import json

# %%
load_dotenv()
# Out:
# True

# %%
url = "https://api.notion.com/v1/search"

# %%
headers = {
    "Authorization": f"Bearer {os.getenv('NOTION_TOKEN')}", 
    "Content-Type": "application/json", 
    "Notion-Version": "2025-09-03"
}

# %%
body={
    "filter":{
        "property":"object",
        "value":"data_source"
    }
    
}

# %%
response = requests.post(url, headers=headers, json=body)
data= response.json()

# %%
print(len(data.get('results')))
# Out:
# 1

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "object": "list",
#   "results": [
#     {
#       "object": "data_source",
#       "id": "2d5c7f92-134f-8163-86a3-000b3d1ad880",
#       "cover": null,
#       "icon": {
#         "type": "emoji",
#         "emoji": "\ud83c\udf3f"
#       },
#       "created_time": "2025-12-26T15:39:00.000Z",
#       "created_by": {
#         "object": "user",
#         "id": "1d19fe38-2fe0-4051-9edc-49b1e5466f44"
#       },
#       "last_edited_by": {
#         "object": "user",
#         "id": "1d19fe38-2fe0-4051-9edc-49b1e5466f44"
#       },
#       "last_edited_time": "2025-12-29T10:29:00.000Z",
#       "title": [
#         {
#           "type": "text",
#           "text": {
#             "content": "Tracker Database",
#             "link": null
#           },
#           "annotations": {
#             "bold": false,
#             "italic": false,
#             "strikethrough": false,
#             "underline": false,
#             "code": false,
#             "color": "default"
#           },
#           "plain_text": "Tracker Database",
#           "href": null
#         }
#       ],
#       "description": [],
#       "is_inline": true,
#       "properties": {
#         "Date Started": {
#           "id": "OQHx",
#           "name": "Date Started",
#           "description": null,
#           "type": "date",
#           "date": {}
#         },
#         "Subject": {
#           "id": "VhNW",
#           "name": "Subject",
#           "description": null,
#           "type": "select",
#           "select": {
#             "options": [
#               {
#                 "id": "X\\te",
#                 "name": "Raspberry PI",
#                 "color": "red",
#                 "description": null
#               },
#               {
#                 "id": "eGUx",
#                 "name": "Machine Learning",
#                 "color": "pink",
#                 "description": null
#               },
#               {
#                 "id": ":~rI",
#                 "name": "Data Engineering",
#                 "color": "default",
#                 "description": null
#               },
#               {
#                 "id": "zst\\",
#                 "name": "Business Analytics",
#                 "color": "purple",
#                 "description": null
#               },
#               {
#                 "id": "S@MX",
#                 "name": "Sql",
#                 "color": "orange",
#                 "description": null
#               },
#               {
#                 "id": "alZR",
#                 "name": "Python",
#                 "color": "yellow",
#                 "description": null
#               },
#               {
#                 "id": "80d9a02e-610f-405e-b235-fbeaabb877b0",
#                 "name": "Data Vizualisation",
#                 "color": "blue",
#                 "description": null
#               },
#               {
#                 "id": "977cf168-0bf4-4004-8da9-95e1bd3b6d90",
#                 "name": "Entrepreneurship",
#                 "color": "brown",
#                 "description": null
#               },
#               {
#                 "id": "08628b12-99c4-472b-ad80-5fcbe5c9a992",
#                 "name": "Gypsy Jazz",
#                 "color": "green",
#                 "description": null
#               },
#               {
#                 "id": "8f0c1235-4b0c-4fcb-8f76-c0e724f671fa",
#                 "name": "Synthesis",
#                 "color": "gray",
#                 "description": null
#               },
#               {
#                 "id": "6e02d71b-e292-4b6f-81c4-33e294384659",
#                 "name": "Web Development",
#                 "color": "gray",
#                 "description": null
#               },
#               {
#                 "id": "ecf3e146-fcc2-4866-a87d-2ec873914c80",
#                 "name": "Godot",
#                 "color": "yellow",
#                 "description": null
#               },
#               {
#                 "id": "82c5edcf-6782-4cd9-9726-c60b5c438baf",
#                 "name": "Negative Development",
#                 "color": "default",
#                 "description": null
#               },
#               {
#                 "id": "134ec5c6-92b1-4d25-8099-67afa458ebaa",
#                 "name": "Field Recording",
#                 "color": "yellow",
#                 "description": null
#               },
#               {
#                 "id": "9cf8e05f-48d5-49b0-af13-c3be6d10ddfc",
#                 "name": "Cloud Architecture",
#                 "color": "purple",
#                 "description": null
#               }
#             ]
#           }
#         },
#         "Priority": {
#           "id": "Xz%5De",
#           "name": "Priority",
#           "description": null,
#           "type": "select",
#           "select": {
#             "options": [
#               {
#                 "id": "<s~i",
#                 "name": "low",
#                 "color": "red",
#                 "description": null
#               },
#               {
#                 "id": "XVlp",
#                 "name": "Medium",
#                 "color": "green",
#                 "description": null
#               },
#               {
#                 "id": "a:xW",
#                 "name": "High",
#                 "color": "pink",
#                 "description": null
#               }
#             ]
#           }
#         },
#         "Source": {
#           "id": "%5D%3D%3CR",
#           "name": "Source",
#           "description": null,
#           "type": "select",
#           "select": {
#             "options": [
#               {
#                 "id": "R^:J",
#                 "name": "Youtube",
#                 "color": "red",
#                 "description": null
#               },
#               {
#                 "id": "mkyS",
#                 "name": "Article",
#                 "color": "pink",
#                 "description": null
#               },
#               {
#                 "id": "eQ[n",
#                 "name": "Book",
#                 "color": "blue",
#                 "description": null
#               },
#               {
#                 "id": "CfoJ",
#                 "name": "Course",
#                 "color": "purple",
#                 "description": null
#               },
#               {
#                 "id": "94c89b5b-66b6-4281-8332-140b296fb6a6",
#                 "name": "Udemy",
#                 "color": "orange",
#                 "description": null
#               }
#             ]
#           }
#         },
#         "Scope": {
#           "id": "%5EKZ%3A",
#           "name": "Scope",
#           "description": null,
#           "type": "select",
#           "select": {
#             "options": [
#               {
#                 "id": "?WIx",
#                 "name": "Epic",
#                 "color": "purple",
#                 "description": null
#               },
#               {
#                 "id": "Vb>@",
#                 "name": "Long",
#                 "color": "orange",
#                 "description": null
#               },
#               {
#                 "id": "P{?s",
#                 "name": "Medium",
#                 "color": "blue",
#                 "description": null
#               },
#               {
#                 "id": "D>;f",
#                 "name": "Quick Win",
#                 "color": "green",
#                 "description": null
#               }
#             ]
#           }
#         },
#         "Status": {
#           "id": "%5Ex%40G",
#           "name": "Status",
#           "description": null,
#           "type": "status",
#           "status": {
#             "options": [
#               {
#                 "id": "5c040be1-d4ad-4799-962b-c6a375de30d9",
#                 "name": "Not started",
#                 "color": "default",
#                 "description": null
#               },
#               {
#                 "id": "213bc66f-45c6-42a9-b545-0195cefaca84",
#                 "name": "In progress",
#                 "color": "orange",
#                 "description": null
#               },
#               {
#                 "id": "831192fd-f990-4196-93ee-04400ddd5d40",
#                 "name": "Completed",
#                 "color": "green",
#                 "description": null
#               }
#             ],
#             "groups": [
#               {
#                 "id": "24d8cbdf-98ce-4e1e-84d9-862411f7c193",
#                 "name": "To-do",
#                 "color": "gray",
#                 "option_ids": [
#                   "5c040be1-d4ad-4799-962b-c6a375de30d9"
#                 ]
#               },
#               {
#                 "id": "9dc648e3-6c30-4207-b5a4-b07841554219",
#                 "name": "In progress",
#                 "color": "blue",
#                 "option_ids": [
#                   "213bc66f-45c6-42a9-b545-0195cefaca84"
#                 ]
#               },
#               {
#                 "id": "61c182e5-07a1-4dbf-bb8d-9ebd324f8a14",
#                 "name": "Complete",
#                 "color": "green",
#                 "option_ids": [
#                   "831192fd-f990-4196-93ee-04400ddd5d40"
#                 ]
#               }
#             ]
#           }
#         },
#         "URL": {
#           "id": "jB%40H",
#           "name": "URL",
#           "description": null,
#           "type": "url",
#           "url": {}
#         },
#         "Topic": {
#           "id": "uhm%3A",
#           "name": "Topic",
#           "description": null,
#           "type": "select",
#           "select": {
#             "options": [
#               {
#                 "id": "XrT|",
#                 "name": "Entrepreneurship",
#                 "color": "pink",
#                 "description": null
#               },
#               {
#                 "id": "\\gEY",
#                 "name": "Drawing/Painting",
#                 "color": "red",
#                 "description": null
#               },
#               {
#                 "id": "?r|I",
#                 "name": "Music",
#                 "color": "brown",
#                 "description": null
#               },
#               {
#                 "id": "?o]J",
#                 "name": "Software Engineering",
#                 "color": "purple",
#                 "description": null
#               },
#               {
#                 "id": "wYFw",
#                 "name": "Data",
#                 "color": "blue",
#                 "description": null
#               },
#               {
#                 "id": "73e727d4-a8c8-4ae0-9375-1826ecc61707",
#                 "name": "Video Games",
#                 "color": "orange",
#                 "description": null
#               },
#               {
#                 "id": "aa0cfb6e-c9de-4af8-8714-9ded0debe3fd",
#                 "name": "Photo",
#                 "color": "gray",
#                 "description": null
#               }
#             ]
#           }
#         },
#         "Title": {
#           "id": "title",
#           "name": "Title",
#           "description": null,
#           "type": "title",
#           "title": {}
#         }
#       },
#       "parent": {
#         "type": "database_id",
#         "database_id": "2d5c7f92-134f-81df-9e09-ed8acead0fad"
#       },
#       "database_parent": {
#         "type": "page_id",
#         "page_id": "2d5c7f92-134f-819a-a920-cca82e474f98"
#       },
#       "url": "https://www.notion.so/2d5c7f92134f81df9e09ed8acead0fad",
#       "public_url": null,
#       "archived": false,
#       "in_trash": false
#     }
#   ],
#   "next_cursor": null,
#   "has_more": false,
#   "type": "page_or_data_source",
#   "page_or_data_source": {},
#   "request_id": "fc878c1a-fb7a-4657-94ba-c656958955ac"
# }

# %%
print(data.get('results'))
